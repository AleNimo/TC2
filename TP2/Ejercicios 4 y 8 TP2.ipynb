# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# ### PDF con desarrollo

# %%
from IPython.display import IFrame
IFrame("./TP2_EJ4.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TP2_EJ4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulación en LTSpice

# %% [markdown]
# Circuito de secciones pasivas:
# ![imagen-2.png](attachment:imagen-2.png)
# ![imagen-3.png](attachment:imagen-3.png)
#
# Circuito con inductores activadas:
# ![imagen-4.png](attachment:imagen-4.png)
# ![imagen-5.png](attachment:imagen-5.png)
# Se superponen completamente en fase y módulo

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# ### PDF con desarrollo

# %%
from IPython.display import IFrame
IFrame("./TP2_EJ8.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TP2_EJ8.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulación en LTSpice

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
# ![imagen-2.png](attachment:imagen-2.png)
