# %% [markdown]
# # Trabajo Semanal 3

# %%
from IPython.display import IFrame
IFrame("./TS3.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Simulación Circuital de Pasa-Altos pasivo y Activado
#
# ### Circuito Pasivo con buffer entre etapas:
#
# ![imagen-5.png](attachment:imagen-5.png)
#
# ### Circuito con inductores activados, tambien separando etapas con buffer:
#
# ![imagen-6.png](attachment:imagen-6.png)
#
# ### Análisis en frecuencia:
#
# ![imagen-11.png](attachment:imagen-11.png)
#
# ### Se observa que en módulo se comportan de la misma manera hasta los 100Khz donde el ancho de banda de los operacionales comienza a afectar al circuito activado. La fase se ve afectada desde los 10Khz
#
# ### Ambos logran los valores especificación del filtro deseado:
#
# ![imagen-8.png](attachment:imagen-8.png)
#
# ![imagen-10.png](attachment:imagen-10.png)
#
# ### Aunque en el circuito activado la atenuación máxima a frecuencia de 3.5Khz es menor a 1dB, probablemente causado de redondeos y parámetros de los operacionales que hacen que no sean del todo ideales.

# %% [markdown]
# ## Simulación numérica Pasa-Altos

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from scipy import signal as sig # módulo de SciPy

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_lti

# Para que el tamaño de la salida sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

# Estilo de los gráficos
##############################################################
fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

npoints = 1000
##############################################################

#Gráfico del pasa altos

R1 = 1e3
R2 = 414.2199

C = 99.4834e-9
L = 29.138e-3

num = np.array([1,0,0])
den1 = np.array([1, R1/L, 1/(L*C)])
den2 = np.array([1, R2/L, 1/(L*C)])

sistema = sig.TransferFunction(np.convolve(num, num),np.convolve(den1, den2))

pretty_print_lti(sistema)

analyze_sys(sistema,3,6) #Funcion cambiada para poder determinar frec inicial y final de gráficos
# Out:
# $\displaystyle \frac{s^4 }{s^4 + s^3 \,\, 4.854e+04 + s^2 \,\, 1.178e+09 + s \,\, 1.674e+13 + 1.19e+17 }$
