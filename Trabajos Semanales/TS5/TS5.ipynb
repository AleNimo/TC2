# %% [markdown]
# # Trabajo Semanal 5

# %%
from IPython.display import IFrame
IFrame("./TS5.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS5.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Punto 1

# %% [markdown]
# ## Simulación Numérica

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from scipy import signal as sig # módulo de SciPy

# un módulo adaptado a mis necesidades
import splane as tc2

# Para que el tamaño de la salida sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

# Estilo de los gráficos
##############################################################
fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

npoints = 1000
##############################################################

#Para rotar la fase sin afectar al módulo se emplea un pasa-todo:
pasa_todo = sig.TransferFunction([1, -1],[1, 1])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(pasa_todo)

tc2.analyze_sys(pasa_todo,-3,3)
# Out:
# $\displaystyle \frac{s +  -1 }{s +   1 }$

# %% [markdown]
# ## Simulación circuital de implemetaciones pasiva y activa:
#
# ### Circuito Pasivo:
# ![imagen-10.png](attachment:imagen-10.png)
#
# ### Circuito Activo:
# ![imagen-11.png](attachment:imagen-11.png)
#
# ### Fase (y módulo) de la trasferecia de ambos circuitos superpuestos:
# ![imagen-9.png](attachment:imagen-9.png)
#
# Se observa que la fase es idéntica y cumple con tener 15° menos que con w=0 (165° respecto de los 180° iniciales), pero que el módulo es 0dB para el circuito activo (K=1) y -6dB para el circuito pasivo (K=0.5).

# %% [markdown]
# # Punto 2

# %% [markdown]
# ## Item A:

# %%
#Parámetros
Qp=1/np.sqrt(2)
K=0.23713737
Wn=2
Wp=0.97393505

notch_PB = sig.TransferFunction([K, 0, K*Wn**2],[1, Wp/Qp, Wp**2])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(notch_PB)

tc2.analyze_sys(notch_PB,-3,3)
# Out:
# $\displaystyle \frac{s^2 \,\, 0.2371 + 0.9485 }{s^2 + s \,\, 1.377 + 0.9485 }$

# %% [markdown]
# ## Implementación Pasiva:
#
# ### Circuito:
# ![imagen.png](attachment:imagen.png)
#
# ### Módulo:
# ![imagen-2.png](attachment:imagen-2.png)
# El circuito fue normalizado según la frecuencia Wn, por lo que el cero de transmisión se encuetra en w=1 (f=159.15mHz) y vemos que para w->inf tiende a -12.5dB.

# %% [markdown]
# ## Item B:

# %%
#Parámetros
Qp=1/np.sqrt(2)
Qn=np.sqrt(2)
K=1
Wn=1
Wp=1

Elimina_Banda = sig.TransferFunction([K, Wn/Qn, K*Wn**2],[1, Wp/Qp, Wp**2])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(Elimina_Banda)

tc2.analyze_sys(Elimina_Banda,-3,3)
# Out:
# $\displaystyle \frac{s^2 + s \,\, 0.7071 +   1 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# ## Implementación Pasiva:
#
# ### Circuito:
# ![imagen-3.png](attachment:imagen-3.png)
#
# ### Módulo:
# ![imagen-5.png](attachment:imagen-5.png)

# %% [markdown]
# ## Item C:

# %%
#Parámetros
Qp=1/np.sqrt(2)
Qn=Qp
Wn=0.5
Wp=Wn

Pasa_Todo = sig.TransferFunction([1, -Wn/Qn, Wn**2],[1, Wp/Qp, Wp**2])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(Pasa_Todo)

tc2.analyze_sys(Pasa_Todo,-3,3)
# Out:
# $\displaystyle \frac{s^2 + s \,\, -0.7071 + 0.25 }{s^2 + s \,\, 0.7071 + 0.25 }$

# %% [markdown]
# ## Implementación Pasiva:
#
# ### Circuito:
# ![imagen-6.png](attachment:imagen-6.png)
#
# ### Fase:
# ![imagen-7.png](attachment:imagen-7.png)
# El circuito fue normalizado según la frecuencia W0=0.5, por lo que el valor de fase intermedio (-pi) se encuetra en w=1 (f=159.15mHz).

# %% [markdown]
# ## Item D:

# %%
#Parámetros
Qp=1/np.sqrt(2)
K=1 #Indeterminable
Wn=4
Wp=1

notch_PB = sig.TransferFunction([K, 0, K*Wn**2],[1, Wp/Qp, Wp**2])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(notch_PB)

tc2.analyze_sys(notch_PB,-3,3)
# Out:
# $\displaystyle \frac{s^2 +  16 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# ## Implementación Pasiva:
#
# ### Circuito:
# ![imagen-8.png](attachment:imagen-8.png)
#
# ### Fase:
# ![imagen-9.png](attachment:imagen-9.png)
# Se observa que a f=159.16mHz (aprox. w=1) tenemos la mitad del recorrido de la fase $\left(-\frac{\pi}{2}\right)$ y a f=636.6mHz (aprox. w=4) tenemos la discontinuidad de salto finito (pi rad).

# %% [markdown]
# # Punto 3

# %%
#Parámetros

Pasa_Banda = sig.TransferFunction([6, 0],[1, 6, 4])

#Muestro la expresión de la transferencia
tc2.pretty_print_lti(Pasa_Banda)

tc2.analyze_sys(Pasa_Banda,-3,3)
# Out:
# $\displaystyle \frac{s \,\,   6 }{s^2 + s \,\,   6 +   4 }$

# %% [markdown]
# ## Implementación Pasiva:
#
# ### Circuito:
# ![imagen-10.png](attachment:imagen-10.png)
#
# ### Fase:
# ![imagen-11.png](attachment:imagen-11.png)
# Se observa que a w=2 (f=318.31mHz) se tiene la mitad del recorrido de la fase (0°), y que la fase inicial (w=0) y final es 90° y -90° respectivamente.
